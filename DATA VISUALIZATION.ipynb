# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
data=pd.read_excel('data 1.xlsx', dtype=object)
data
# Out:
#          WEEK Game: GLOBAL Museum: GLOBAL
# 0  2020-02-02           80             14
# 1  2020-02-09           78             15
# 2  2020-02-16           84             17
# 3  2020-02-23           77             15
# 4  2020-03-01           74             13
# 5  2020-03-08           73             12
# 6  2020-03-15           78              7
# 7  2020-03-22           90              6
# 8  2020-03-29           90              6
# 9  2020-04-05           94              5
# 10 2020-04-12           95              6
# 11 2020-04-19           90              6
# 12 2020-04-26           90              6
# 13 2020-05-03           89              6
# 14 2020-05-10           82              6
# 15 2020-05-17           84              7
# 16 2020-05-24           79              7
# 17 2020-05-31           74              7
# 18 2020-06-07           75              8
# 19 2020-06-14           77              8
# 20 2020-06-21           79              8
# ...

# %%
# Out:
# <function __main__.data_line()>

# %%
plt.plot(data['WEEK'], data['Game: GLOBAL'], label="Game: GLOBAL")
plt.plot(data['WEEK'], data['Museum: GLOBAL'], label="Museum: GLOBAL")
plt.legend()
plt.title("Global Search Volume Index")
plt.xlabel("DATE")
plt.ylabel("VOLUME INDEX MARK")

plt.savefig("Global Search Volume Index.jpg")
plt.show()
